# %%
# Install a pip package in the current Jupyter kernel
import sys
import json
# !{sys.executable} -m pip install pdfx tika
# Out:
# Requirement already satisfied: pdfx in /anaconda3/lib/python3.6/site-packages (1.3.0)
# Requirement already satisfied: tika in /anaconda3/lib/python3.6/site-packages (1.19)
# Requirement already satisfied: chardet in /anaconda3/lib/python3.6/site-packages (from pdfx) (3.0.4)
# Requirement already satisfied: pdfminer2 in /anaconda3/lib/python3.6/site-packages (from pdfx) (20151206)
# Requirement already satisfied: requests in /anaconda3/lib/python3.6/site-packages (from tika) (2.18.4)
# Requirement already satisfied: setuptools in /anaconda3/lib/python3.6/site-packages (from tika) (38.4.0)
# Requirement already satisfied: six in /anaconda3/lib/python3.6/site-packages (from pdfminer2->pdfx) (1.11.0)
# Requirement already satisfied: idna<2.7,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests->tika) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests->tika) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests->tika) (2018.1.18)
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pdfx
paperdirectory = "/Users/fernandodurier/Desktop/sarcasm-paper-review"
import os
set_of_refs = []
for root, dirs, files in os.walk(paperdirectory, topdown=False):
    for name in files:
        if ".pdf" in name:
            pdfpath = os.path.join(root, name)
            pdf = pdfx.PDFx(pdfpath)
            metadata = pdf.get_metadata()
            references_list = pdf.get_references()
            references_dict = pdf.get_references_as_dict()
            pdfmeta = {"meta":metadata, "references":references_dict}
            set_of_refs.append(pdfmeta)

# %%
print('-------------------------------------------------------------')
for ref in set_of_refs:
    print('meta: ', ref['meta'])
    print('references: ', ref['references'])
    print('-------------------------------------------------------------')
# Out:
# -------------------------------------------------------------
# meta:  {'AuthoritativeDomain[1]': 'sciencedirect.com', 'AuthoritativeDomain[2]': 'elsevier.com', 'CreationDate': "D:20120824160310+05'30'", 'CrossMarkDomains[1]': 'sciencedirect.com', 'CrossMarkDomains[2]': 'elsevier.com', 'CrossmarkDomainExclusive': '2010-04-23', 'CrossmarkMajorVersionDate': '2010-04-23', 'ElsevierWebPDFSpecifications': '6.5', 'ModDate': "D:20130220162050+05'30'", 'Producer': 'Acrobat Distiller 9.0.0 (Windows)', 'doi': '10.1016/j.procs.2018.10.409', 'robots': 'noindex', 'xap': {'CreateDate': '2012-08-24T16:03:10+05:30', 'CreatorTool': 'Elsevier', 'ModifyDate': '2013-02-20T16:20:50+05:30', 'MetadataDate': '2013-02-20T16:20:50+05:30'}, 'pdf': {'Producer': 'Acrobat Distiller 9.0.0 (Windows)', 'Keywords': 'Sarcasm; Classification; Feature Selection; k-means clustering'}, 'dc': {'format': 'application/pdf', 'identifier': 'doi:10.1016/j.procs.2018.10.409', 'title': {'x-default': 'Sarcasm classification: A novel approach by using Content Based Feature Selection Method'}, 'creator': ['H M Keerthi Kumar', 'B S Harish'], 'description': {'x-default': 'Procedia Computer Science, 143 (2018) 378-386. doi:10.1016/j.procs.2018.10.409'}, 'publisher': ['Elsevier B.V.'], 'subject': ['Sarcasm', 'Classification', 'Feature Selection', 'k-means clustering']}, 'xapmm': {'DocumentID': 'uuid:fd8cfc10-4791-4a8b-8025-00abb91efa0c', 'InstanceID': 'uuid:d56e5e26-6274-4fa7-ad08-30fc2ecddb91'}, 'http://prismstandard.org/namespaces/basic/3.0/': {'aggregationType': 'journal', 'copyright': '© 2018 The Author(s). Published by Elsevier B.V.', 'publicationName': 'Procedia Computer Science', 'issn': '1877-0509', 'volume': '143', 'doi': '10.1016/j.procs.2018.10.409', 'url': 'https://doi.org/10.1016/j.procs.2018.10.409', 'startingPage': '378', 'endingPage': '386', 'pageRange': '378-386', 'coverDisplayDate': '2018'}, 'pdfx': {'f': '6e3bdb61-db2f-41b8-8079-17d13bc025b6:1553720621          ', 'CrossmarkMajorVersionDate': '2010-04-23', 'CrossmarkDomainExclusive': 'true', 'doi': '10.1016/j.procs.2018.10.409', 'robots': 'noindex', 'AuthoritativeDomain': ['sciencedirect.com', 'elsevier.com'], 'CrossMarkDomains': ['sciencedirect.com', 'elsevier.com']}, 'http://www.niso.org/schemas/ali/1.0/': {'license_ref': [None]}, 'http://www.niso.org/schemas/jav/1.0/': {'journal_article_version': 'VoR'}, 'crossmark': {'CrossmarkDomainExclusive': 'true', 'MajorVersionDate': '2010-04-23', 'DOI': '10.1016/j.procs.2018.10.409', 'CrossMarkDomains': ['sciencedirect.com', 'elsevier.com']}, 'rights': {'Marked': 'True'}, 'Pages': 9}
# references:  {'url': ['ac.in', '10.5120/ijca2017913711', 'www.elsevier.com/locate/procedia', 'www.sciencedirect.com', 'https://creativecommons.org/licenses/by-nc-nd/4.0/', 'https://doi.org/10.1016/j.jesit.2017.06.004', 'http://dx.doi.org/10.1155/2014/717092']}
# -------------------------------------------------------------
# meta:  {'Author': 'Sandeepa Kannangara', 'CreationDate': "D:20171212120259+11'00'", 'Creator': 'LaTeX with hyperref package', 'Keywords': 'Fine-Grained Opinion Mining; Ideology Detection; Sarcasm Detection ', 'ModDate': "D:20180104074818-05'00'", 'PTEX.Fullbanner': 'This is MiKTeX-pdfTeX 2.9.6211 (1.40.17)', 'Producer': 'pdfTeX-1.40.17', 'Title': 'Mining Twitter for Fine-Grained Political Opinion Polarity Classification, Ideology Detection and Sarcasm Detection', 'Trapped': 'False', 'dc': {'format': 'application/pdf', 'creator': ['Sandeepa Kannangara'], 'description': {'x-default': None}, 'title': {'x-default': 'Mining Twitter for Fine-Grained Political Opinion Polarity Classification, Ideology Detection and Sarcasm Detection'}}, 'xap': {'CreateDate': '2017-12-12T12:02:59+11:00', 'CreatorTool': 'LaTeX with hyperref package', 'ModifyDate': '2018-01-04T07:48:18-05:00', 'MetadataDate': '2018-01-04T07:48:18-05:00'}, 'pdf': {'Keywords': 'Fine-Grained Opinion Mining; Ideology Detection; Sarcasm Detection ', 'Producer': 'pdfTeX-1.40.17', 'Trapped': 'False'}, 'pdfx': {'PTEX.Fullbanner': 'This is MiKTeX-pdfTeX 2.9.6211 (1.40.17)'}, 'xapmm': {'DocumentID': 'uuid:bfac9d28-ba7c-4530-9893-7974fa11ab9b', 'InstanceID': 'uuid:684fea1d-1ad1-408a-9409-42416a3854b2'}, 'Pages': 2}
# references:  {'url': ['https://doi.org/10.1145/3159652.3170461', 'edu.au']}
# -------------------------------------------------------------
# meta:  {'CreationDate': 'D:20170905011807Z', 'Creator': 'LaTeX with hyperref package', 'ModDate': 'D:20170905011807Z', 'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'Producer': 'pdfTeX-1.40.17', 'Trapped': 'False', 'Pages': 15}
# references:  {'url': ['grants.g0v.tw/projects/588fa7b382223f001e022944', 'www.journalism.org/2016/05/26/news-use-across-', 'www.buzzfeed.com/craigsilverman/viral-', 'compsocial.github.io/CREDBANK-data/', 'en.wikipedia.org/wiki/Pizzagate', 'www.nytimes.com/2016/11/28/opinion/fake-', 'www.snopes.com/', 'comprop.oii.ox.ac.uk/2016/11/18/resource-for-', 'www.fakenewschallenge.org/', '1703.07823', 'github.com/KaiDMML/FakeNewsNet', 'www.cs.ucsb.edu/', 'github.com/BuzzFeedNews/2016-10-facebook-', '1703.06988', 'www.politico.com/magazine/story/2016/12/fake-', '1704.00656', '1705.00648', 'time.com/4783932/inside-russia-social-media-war-', '1702.05638', 'www.bbc.com/news/uk-36528256', 'github.com/bs-detector/bs-detector', '1704.07506', 'www.kaggle.com/mrisdal/fake-news', '1703.06959', 'www.wired.com/2016/12/photos-fuel-spread-fake-', 'www.politifact.com/']}
# -------------------------------------------------------------
# meta:  {'Author': 'Victoria Rubin ; Niall Conroy ; Yimin Chen ; Sarah Cornwell', 'Title': 'Fake News or Truth? Using Satirical Cues to Detect Potentially Misleading News', 'Subject': 'W16-08 2016', 'Creator': 'LaTeX with hyperref package', 'Producer': 'pdfTeX-1.40.3', 'CreationDate': "D:20160607141025-07'00'", 'ModDate': "D:20160607141025-07'00'", 'Trapped': 'False', 'PTEX.Fullbanner': 'This is pdfTeX using libpoppler, Version 3.141592-1.40.3-2.2 (Web2C 7.5.6) kpathsea version 3.5.6', 'Pages': 11}
# references:  {'url': ['na-tionalreport.net', '10.1007/s10579-012-9196-x', 'http://scikit-learn.org', '10.1177/0002764210376309', 'www.cbc.ca/punchline', 'www.thespoof.com', 'syruptrap.ca', '10.1080/00220973.1988.10806492', 'thepeoplescube.com', 'http://literallyunbelievable.org/', 'gc.ca/pub/75-006-x/2014001', '10.1007/s10115-013-0652-8', '10.1002/asi.23216', '10.1016/j.datak.2012', '10.1177/', 'http://www.gallup.com/poll/185927/americans-trust-media-remains-historical-low.aspx', 'dic-tionary.com', 'http://www.statcan', '10.1016/s0304-422x(97)00006-5', 'http://victoriarubin.fims.uwo.ca/news-verification/', 'urbananomie.com', 'worldnewsdailyreport.com', 'http://dx.doi.org/10.1016/S0378-2166(99)', '10.1515/humor-2012-0019', 'thelapine.ca', 'dailycurrant.com', 'www.thecodfish.com', 'https://www.americanpressinstitute.org/publications/reports/survey-research/rational-attentive-news-consumer/', 'http://hdl.handle.net/', 'https://www.washingtonpost.com/news/worldviews/wp/2015/06/02/7-times-the-onion-was-lost-in-translation', 'http://www.nltk.org/', 'www.newyorker.com/humor/borowitz-report', 'http://www3', 'https://youtu.be/2X93u3anTco', '10.1016/j.chb.2015', 'http://firstmonday.org/ojs/index.php/fm/article/view/3933/3170'], 'pdf': ['wefo-rum.org/docs/WEF_GlobalRisks_Report_2013.pdf', 'http://www.theopen-road.com/wp-content/uploads/2012/09/Power-principles-and-the-press-Open-Road-and-Populus1.pdf']}
# -------------------------------------------------------------
# meta:  {'Producer': 'pdfTeX-1.40.16', 'Creator': 'TeX', 'CreationDate': "D:20161123111340+01'00'", 'ModDate': "D:20161123111340+01'00'", 'Trapped': 'False', 'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015/Debian) kpathsea version 6.2.1', 'Pages': 7}
# references:  {'url': ['uniroma2.it', 'www.tensorflow.org/']}
# -------------------------------------------------------------
# meta:  {'CreationDate': 'D:20170906002223Z', 'Creator': 'LaTeX with hyperref package', 'ModDate': 'D:20170906002223Z', 'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'Producer': 'pdfTeX-1.40.17', 'Trapped': 'False', 'Pages': 11}
# references:  {'url': ['https://www.theguardian.com/media/2016/nov/17/facebook-fake-news-satire', '1509.06664', '1406.1078', 'github.com/fYYw/satire', '1703.09398', '1409.0473', '1211.5590', 'http://www.aclweb.org/anthology/W16-0802', 'http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html', 'http://is.muni.cz/publication/884893/en', '1602.03426', 'www.theguardian.com/media/2016/nov/17/facebook-', '1702.05638', '1703.07823', 'http://is.muni.cz/', 'https://github.com/fYYw/satire', 'http://www.aclweb.org/anthology/P16-1101', '1606.02858']}
# -------------------------------------------------------------
# meta:  {'Author': 'Eleni Kapogianni', 'CreationDate': "D:20160107110504+05'30'", 'Creator': 'Elsevier', 'CrossMarkDomains[1]': 'sciencedirect.com', 'CrossMarkDomains[2]': 'elsevier.com', 'CrossmarkDomainExclusive': 'true', 'CrossmarkMajorVersionDate': '2010-04-23', 'ElsevierWebPDFSpecifications': '6.5', 'ModDate': "D:20160107110504+05'30'", 'Producer': 'Acrobat Distiller 9.0.0 (Windows)', 'Subject': 'Journal of Pragmatics, 91 (2016) 16-28. doi:10.1016/j.pragma.2015.11.001', 'Title': 'The ironic operation: Revisiting the components of ironic meaning', 'doi': '10.1016/j.pragma.2015.11.001', 'robots': 'noindex', 'dc': {'format': 'application/pdf', 'identifier': '10.1016/j.pragma.2015.11.001', 'title': {'x-default': 'The ironic operation: Revisiting the components of ironic meaning'}, 'creator': ['Eleni Kapogianni'], 'subject': ['Irony', 'Ironic operation', 'Ironic vehicle', '(Direct) ironic output'], 'description': {'x-default': 'Journal of Pragmatics, 91 (2016) 16-28. doi:10.1016/j.pragma.2015.11.001'}, 'publisher': ['Elsevier B.V.']}, 'http://prismstandard.org/namespaces/basic/3.0/': {'aggregationType': 'journal', 'publicationName': 'Journal of Pragmatics', 'copyright': '© 2015 Elsevier B.V. All rights reserved.', 'issn': '0378-2166', 'volume': '91', 'coverDisplayDate': 'January 2016', 'coverDate': '2016-01', 'pageRange': '16-28', 'startingPage': '16', 'endingPage': '28', 'doi': '10.1016/j.pragma.2015.11.001', 'url': 'http://dx.doi.org/10.1016/j.pragma.2015.11.001'}, 'crossmark': {'MajorVersionDate': '2010-04-23', 'CrossmarkDomainExclusive': 'true', 'DOI': '10.1016/j.pragma.2015.11.001', 'CrossMarkDomains': ['elsevier.com', 'sciencedirect.com']}, 'http://www.niso.org/schemas/jav/1.0/': {'journal_article_version': 'VoR'}, 'pdfx': {'f': 'd6bcf2c8-4d2b-40e1-ba90-78a107c117af:1553720496          ', 'doi': '10.1016/j.pragma.2015.11.001', 'robots': 'noindex', 'CrossmarkMajorVersionDate': '2010-04-23', 'CrossmarkDomainExclusive': 'true', 'CrossMarkDomains': ['sciencedirect.com', 'elsevier.com']}, 'xap': {'CreatorTool': 'Elsevier', 'ModifyDate': '2016-01-07T11:05:04+05:30', 'CreateDate': '2016-01-07T11:05:04+05:30'}, 'rights': {'Marked': 'True'}, 'pdf': {'Producer': 'Acrobat Distiller 9.0.0 (Windows)'}, 'xapmm': {'DocumentID': 'uuid:21008177-7773-446c-874f-83c833955efc', 'InstanceID': 'uuid:923a3e0e-d257-48b6-a423-93355c8b9f50'}, 'Pages': 13}
# references:  {'url': ['http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0100', 'http://dx.doi.org/10.1037/a0035658', 'http://dx.doi.org/10.1163/18773109-00601007', 'http://dx.doi.org/', 'http://dx.doi.org/10.1111/j.1468-0068.2010.00822.x', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0300', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0030', 'http://dx.doi.org/10.1515/IPRG.2009.015', 'http://dx.doi.org/10.1080/10926488.2012.691750', 'http://dx', 'http://dx.doi.org/10.1016/S0378-2166(01)00045-5', 'http://dx.doi.org/10.1515/humor-2014-0093', 'http://dx.doi.org/10.1080/10926488.2000.9678864', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0210', 'doi.org/10.1016/S0378-2166(99)00005-3', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0160', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0235', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0250', 'http://dx.doi.org/10.1515/', 'http://dx.doi.org/10.1037/a0036630', 'http://dx.doi.org/10.1111/j.1468-', 'http://dx.doi.org/10.1016/j.cogni-', 'http://dx.doi.org/10.1037/0096-3445.113.1.112', 'mailto:e.kapogianni@kent.ac.uk', 'http://dx.doi.org/10.1075/bjl.28.01gio', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0105', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0155', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0190', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0115', 'http://dx.doi.org/10.1515/IPRG', 'www.elsevier.com/locate/pragma', 'http://dx.doi.org/10.1016/S0364-0213(87)80007-1', 'http://dx.doi.org/10.1037/0096-3445.124.1.3', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0260', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0285', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0165', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0265', 'http://dx.doi.org/10.1016/j.cognition.2010.06.005', 'http://dx.doi.org/10.1515/ip-2013-0018', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0145', 'http://www.sciencedirect.com/science/journal/03782166', 'http://dx.doi.org/10.1016/S0378-2166(01)00046-7', 'http://dx.doi.org/10.1016/j.pragma.2007.04.009', 'http://dx.doi.org/10.1037/0096-3445.118.4.374', 'http://dx.doi.org/10.1016/j.pragma.2015.11.001', 'http://dx.doi.org/10.1075/pc.18.2.07gar', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0135', 'http://dx.doi.org/10.1016/S0378-2166(99)00132-0', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0150', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0275', 'dx.doi.org/10.1515/ip-2013-0018', 'http://dx.doi.org/10.1080/10926480701235346', 'http://dx.doi.org/10.1080/10926488.2011.583194', 'http://dx.doi.org/10.1163/18773109-00701003', 'http://dx.doi.org/10.1016/', 'www.sciencedirect.com', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0245', 'http://dx.doi.org/10.1016/j.pragma.2010.11.001', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0270', 'http://dx.doi.org/10.1016/0024-3841(92)90025-E', 'http://crossmark.crossref.org/dialog/?doi=10.1016/j.pragma.2015.11.001&domain=pdf', 'http://dx.doi.org/10.5539/ijel.v3n5p14', 'http://dx.doi.org/10.1515/IPRG. 2011.002', 'http://dx.doi.org/10.1016/j.lingua.2006.05.001', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0055', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0035', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0180', 'http://dx.doi.org/10.1515/humor-2014-0096', 'http://dx.doi.org/10.1016/j', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0185', 'http://dx.doi.org/10.1016/S0378-2166(99)00070-3', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0015', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0120', 'ac.uk', 'http://dx.doi.org/10.1080/0163853X.2014.954951', 'http://refhub.elsevier.com/S0378-2166(15)00306-9/sbref0090', 'http://dx.doi.org/10.1016/S0378-2166(99)00005-3']}
# -------------------------------------------------------------
# meta:  {'Producer': 'pdfTeX-1.40.17', 'Creator': 'TeX', 'CreationDate': 'D:20180703194133Z', 'ModDate': 'D:20180703194133Z', 'Trapped': 'False', 'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016/Debian) kpathsea version 6.2.2', 'Pages': 10}
# references:  {'url': ['http://www.boatos.org/', 'http://fortune.com/2018/04/10/facebook-cambridge-analytica-what-happened/', 'https://medium.com/data-', 'usp.br', 'https://newsroom.fb.com/news/2017/04/working-to-stop-misinformation-and-', 'https://www.theguardian.com/technology/2017/may/07/the-great-british-brexit-', 'Fake.Br', 'https://sites.google.com/icmc.usp.br/opinando/', 'http://piaui.folha.uol.com.br/lupa/']}
# -------------------------------------------------------------
# meta:  {'CrossMarkDomains[2]': 'sciencedirect.com', 'CreationDate': "D:20160311081230+05'30'", 'CrossmarkMajorVersionDate': '2010-04-23', 'Subject': 'Engineering Applications of Artificial Intelligence, 51 + (2016) 50-57. doi:10.1016/j.engappai.2016.01.007', 'Author': 'Basilis Charalampakis', 'Creator': 'Elsevier', 'Keywords': 'Irony detection; Text mining; Twitter; Politics', 'ElsevierWebPDFSpecifications': '6.5', 'CrossmarkDomainExclusive': 'true', 'robots': 'noindex', 'ModDate': "D:20160311081230+05'30'", 'doi': '10.1016/j.engappai.2016.01.007', 'CrossMarkDomains[1]': 'elsevier.com', 'Title': 'A comparison between semi-supervised and supervised text mining techniques on detecting irony in greek political tweets', 'dc': {'format': 'application/pdf', 'identifier': 'doi:10.1016/j.engappai.2016.01.007', 'title': {'x-default': 'A comparison between semi-supervised and supervised text mining techniques on detecting irony in greek political tweets'}, 'creator': ['Basilis Charalampakis', 'Dimitris Spathis', 'Elias Kouslis', 'Katia Kermanidis'], 'subject': ['Irony detection', 'Text mining', 'Twitter', 'Politics'], 'publisher': ['Elsevier'], 'description': {'x-default': 'Engineering Applications of Artificial Intelligence, 51 + (2016) 50-57. doi:10.1016/j.engappai.2016.01.007'}}, 'http://prismstandard.org/namespaces/basic/3.0/': {'aggregationType': 'journal', 'publicationName': 'Engineering Applications of Artificial Intelligence', 'copyright': '© 2016 Elsevier Ltd. All rights reserved.', 'issn': '0952-1976', 'volume': '51', 'coverDate': '2016-05-01', 'pageRange': '50-57', 'startingPage': '50', 'endingPage': '57', 'doi': '10.1016/j.engappai.2016.01.007', 'url': 'http://dx.doi.org/10.1016/j.engappai.2016.01.007', 'issueIdentifier': 'C'}, 'crossmark': {'MajorVersionDate': '2010-04-23', 'CrossmarkDomainExclusive': 'true', 'DOI': '10.1016/j.engappai.2016.01.007', 'CrossMarkDomains': ['elsevier.com', 'sciencedirect.com']}, 'pdfx': {'ElsevierWebPDFSpecifications': '6.5', 'doi': '10.1016/j.engappai.2016.01.007', 'CrossmarkMajorVersionDate': '2010-04-23', 'CrossmarkDomainExclusive': 'true', 'robots': 'noindex', 'CrossMarkDomains': ['elsevier.com', 'sciencedirect.com']}, 'http://www.niso.org/schemas/jav/1.0/': {'journal_article_version': 'VoR'}, 'xap': {'CreatorTool': 'Elsevier', 'ModifyDate': '2016-03-11T08:12:30+05:30', 'CreateDate': '2016-03-11T08:12:30+05:30', 'MetadataDate': '2016-03-11T08:12:30+05:30'}, 'rights': {'Marked': 'True'}, 'pdf': {'Keywords': 'Irony detection; Text mining; Twitter; Politics'}, 'xapmm': {'DocumentID': 'uuid:76280a7e-ec55-4927-b2a2-15945e8132aa', 'InstanceID': 'uuid:a9f97f52-44cf-411a-be6b-29ba2ecb5606'}, 'Pages': 8}
# references:  {'url': ['https://github.com/fracpete/collective-classiﬁcation-weka-package', 'trending.gr', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref10', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref5', 'www.sciencedirect.com/science/journal/09521976', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref9', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref4', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref2', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref11', 'http://www.cs.waikato.ac.nz/ml/weka', 'mailto:p11kous@ionio.gr', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref12', 'http://di.ionio.gr/hilab/doku.php?id¼start:websent', 'Slashdot.com', 'http://crossmark.crossref.org/dialog/?doi=10.1016/j.engappai.2016.01.007&domain=pdf', 'mailto:kerman@ionio.gr', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref8', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref7', 'http://dx.doi.org/10.1016/j.engappai.2016.01.007', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref3', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref16', 'mailto:p11char@ionio.gr', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref13', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref14', 'auth.gr', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref1', 'http://di.ionio.gr/hilab/doku.php?id=start:websent', 'mailto:p11spat@ionio.gr', 'www.elsevier.com/locate/engappai', 'mailto:sdimitris@csd.auth.gr', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref15', 'https://github.com/fracpete/collective-classification-weka-package', 'http://refhub.elsevier.com/S0952-1976(16)00011-7/sbref6']}
# -------------------------------------------------------------
# meta:  {'IEEE Issue ID': '8528998', 'Creator': 'Microsoft® Word 2016', 'Producer': 'Acrobat Distiller 8.0.0 (Windows); modified using iText® 7.1.1 ©2000-2018 iText Group NV (AGPL-version)', 'IEEE Article ID': '8529117', 'Title': 'Convolutional Neural Network Based Simile Classification System', 'IEEE Publication ID': '8510758', 'Meeting Ending Date': '13 July 2018', 'Meeting Starting Date': '11 July 2018', 'Subject': '2018 International Conference on Emerging Trends and Innovations In Engineering And Technological Research (ICETIETR);2018; ; ; ', 'ModDate': "D:20181108192440-05'00'", 'CreationDate': "D:20181107123158+05'30'", 'dc': {'format': 'application/pdf', 'publisher': ['IEEE'], 'description': {None: '2018 International Conference on Emerging Trends and Innovations In Engineering And Technological Research (ICETIETR);2018; ; ; '}, 'subject': ['Figurative Language', 'Deep learning', 'Machine Learning', 'ConvolutionalNeuralNetwork', 'Glove', 'Neuralnetwork'], 'title': {None: 'Convolutional Neural Network Based Simile Classification System'}, 'creator': ['P D Manjusha', 'C Raseek']}, 'http://prismstandard.org/namespaces/basic/3.0/': {'publicationName': '2018 International Conference on Emerging Trends and Innovations In Engineering And Technological Research (ICETIETR)', 'startingPage': '1', 'coverDisplayDate': '  July 2018', 'endingPage': '5'}, 'Pages': 5}
# references:  {'url': ['http://www.anc.org/']}
# -------------------------------------------------------------
# meta:  {'AuthoritativeDomain[1]': 'sciencedirect.com', 'AuthoritativeDomain[2]': 'elsevier.com', 'CreationDate': "D:20171106142237+05'30'", 'CrossMarkDomains[1]': 'sciencedirect.com', 'CrossMarkDomains[2]': 'elsevier.com', 'CrossmarkDomainExclusive': '2010-04-23', 'CrossmarkMajorVersionDate': '2010-04-23', 'ElsevierWebPDFSpecifications': '6.5', 'ModDate': "D:20171108191842+05'30'", 'Producer': 'Adobe PDF Library 15.0', 'doi': '10.1016/j.procs.2017.10.105', 'robots': 'noindex', 'xap': {'CreateDate': '2012-08-24T16:03:10+05:30', 'CreatorTool': 'Elsevier', 'ModifyDate': '2013-02-20T16:20:50+05:30', 'MetadataDate': '2013-02-20T16:20:50+05:30'}, 'pdf': {'Producer': 'Acrobat Distiller 9.0.0 (Windows)', 'Keywords': 'Arabic tweets; opinion analysis; irony detection; supervised learning'}, 'dc': {'format': 'application/pdf', 'identifier': 'doi:10.1016/j.procs.2017.10.105', 'title': {'x-default': 'SOUKHRIA: Towards an Irony Detection System for Arabic in Social Media'}, 'creator': ['Jihen Karoui', 'Farah Banamara Zitoune', 'Véronique Moriceau'], 'description': {'x-default': 'Procedia Computer Science, 117 (2017) 161-168. doi:10.1016/j.procs.2017.10.105'}, 'publisher': ['Elsevier B.V.'], 'subject': ['Arabic tweets', 'opinion analysis', 'irony detection', 'supervised learning']}, 'xapmm': {'DocumentID': 'uuid:fd8cfc10-4791-4a8b-8025-00abb91efa0c', 'InstanceID': 'uuid:d56e5e26-6274-4fa7-ad08-30fc2ecddb91'}, 'http://prismstandard.org/namespaces/basic/3.0/': {'aggregationType': 'journal', 'copyright': '© 2017 The Author(s). Published by Elsevier B.V.', 'publicationName': 'Procedia Computer Science', 'issn': '1877-0509', 'volume': '117', 'doi': '10.1016/j.procs.2017.10.105', 'url': 'https://doi.org/10.1016/j.procs.2017.10.105', 'startingPage': '161', 'endingPage': '168', 'pageRange': '161-168', 'coverDisplayDate': '2017'}, 'pdfx': {'f': 'cfdff143-32b6-4340-bd7f-f424ef52a967:1553721250          ', 'CrossmarkMajorVersionDate': '2010-04-23', 'CrossmarkDomainExclusive': 'true', 'doi': '10.1016/j.procs.2017.10.105', 'robots': 'noindex', 'AuthoritativeDomain': ['sciencedirect.com', 'elsevier.com'], 'CrossMarkDomains': ['sciencedirect.com', 'elsevier.com']}, 'http://www.niso.org/schemas/ali/1.0/': {'license_ref': [None]}, 'http://www.niso.org/schemas/jav/1.0/': {'journal_article_version': 'VoR'}, 'crossmark': {'CrossmarkDomainExclusive': 'true', 'MajorVersionDate': '2010-04-23', 'DOI': '10.1016/j.procs.2017.10.105', 'CrossMarkDomains': ['sciencedirect.com', 'elsevier.com']}, 'rights': {'Marked': 'True'}, 'Pages': 8}
# references:  {'url': ['www.elsevier.com/locate/procedia', 'http://alt.qcri.org/semeval2016/task7/', 'http://saifmohammad.com/WebPages/ArabicSA.html', 'http://spardindata.org/', 'www.sciencedirect.com']}
# -------------------------------------------------------------
# meta:  {'CreationDate': 'D:20180131133821Z', 'Creator': 'Word', 'ModDate': "D:20180221140410-05'00'", 'Producer': 'Mac OS X 10.12.6 Quartz PDFContext', 'Title': 'Microsoft Word - Fake News CHI Submission-camera-ready.docx', 'xap': {'CreateDate': '2018-01-31T13:38:21Z', 'CreatorTool': 'Word', 'ModifyDate': '2018-02-21T14:04:10-05:00', 'MetadataDate': '2018-02-21T14:04:10-05:00'}, 'pdf': {'Keywords': None, 'Producer': 'Mac OS X 10.12.6 Quartz PDFContext'}, 'dc': {'format': 'application/pdf', 'title': {'x-default': 'Microsoft Word - Fake News CHI Submission-camera-ready.docx'}}, 'xapmm': {'DocumentID': 'uuid:90d69a7e-0729-4547-8e10-d5064ec30dc8', 'InstanceID': 'uuid:6401b655-2d16-4d4e-a08e-a6d897101ce8'}, 'Pages': 10}
# references:  {'url': ['https://doi.org/10.2307/3089803', 'https://doi.org/10.1109/AEEICB.2017.7972411', 'https://doi.org/10.2307/1252090', 'https://doi.org/10.1177/1555412010377319', 'https://doi.org/10.1080/08838150701308002', 'https://doi.org/10.5210/fm.v21i11.7090', 'https://doi.org/10.13140/2.1.4822.8166', 'https://doi.org/10.1080/15405702.2012.638571', 'https://doi.org/10.1080/21670811.2012.744561', 'https://doi.org/10.1145/1963405.1963500', 'https://doi.org/10.1177/0196859912458700', 'https://doi.org/10.1145/3027063.3053227', 'https://twitter.com/realdonaldtrump/status/8994112540', 'https://doi.org/10.1145/3173574.3173950', 'https://www.theguardian.com/books/2016/nov/15/post-', 'https://doi.org/10.1080/15405702.2012.638567', 'https://doi.org/10.1145/2823465.2823467', 'https://doi.org/10.1002/pra2.2015.145052010083', 'https://doi.org/10.1109/IPDPS.2013.47', 'https://doi.org/10.1057/palgrave.cpt.9300058', 'https://doi.org/10.1177/1461444817706684', 'Retrieved', 'https://doi.org/10.1080/15405702.2012.638566', 'ac.uk', 'https://doi.org/10.1177/0093650212453600'], 'arxiv': ['1704.00656']}
# -------------------------------------------------------------
# meta:  {'PTEX.Fullbanner': 'This is MiKTeX-pdfTeX 2.9.4535 (1.40.13)', 'IEEE Issue ID': '8600701', 'Creator': 'LaTeX with hyperref package', 'Producer': 'pdfTeX-1.40.13; modified using iText® 7.1.1 ©2000-2018 iText Group NV (AGPL-version)', 'IEEE Article ID': '8641269', 'Title': 'Sarcasm Detection Using Soft Attention-Based Bidirectional Long Short-Term Memory Model With Convolution Network', 'IEEE Publication ID': '6287639', 'Subject': 'IEEE Access;2019;7; ;10.1109/ACCESS.2019.2899260', 'ModDate': "D:20190304022342-05'00'", 'Trapped': 'False', 'CreationDate': "D:20190227115328+05'30'", 'dc': {'format': 'application/pdf', 'publisher': ['IEEE'], 'description': {None: 'IEEE Access;2019;7; ;10.1109/ACCESS.2019.2899260'}, 'subject': ['Sarcasm', 'deep learning', 'attention', 'social data'], 'title': {None: 'Sarcasm Detection Using Soft Attention-Based Bidirectional Long Short-Term Memory Model With Convolution Network'}, 'creator': ['Le Hoang Son', 'Akshi Kumar', 'Saurabh Raj Sangwan', 'Anshika Arora', 'Anand Nayyar', 'Mohamed Abdel-Basset']}, 'http://prismstandard.org/namespaces/basic/3.0/': {'publicationName': 'IEEE Access', 'startingPage': '23319', 'coverDisplayDate': '    2019', 'volume': '7', 'doi': '10.1109/ACCESS.2019.2899260', 'endingPage': '23328'}, 'Pages': 10}
# references:  {'url': ['http://dx.doi.org/10.1007/s12145-018-0371-5.', 'https://orcid.org/0000-0002-9821-6146', '10.1002/cpe.5107', 'http://www.ieee.org/publications_standards/publications/rights/index.html', '1www.thesarcasmdetector.com', '10.1007/s00521-018-3442-0', 'https://orcid.org/0000-0002-7967-8732', 'http://hdl.handle.net/2328/27165', '10.1007/s11235-018-0481-x', 'M.Sc', 'https://orcid.org/0000-0003-4263-7168', 'edu.eg', 'http://dx.doi.org/10.1016/j.cie.2018.11.007', '10.1007/s11276-018-1750-z', '10.1007/s12145-018-0371-5', 'http://dx.doi.org/10.1007/s11276-018-1750-z', 'http://dx.doi.org/10.1002/cpe.5107', 'https://orcid.org/0000-0003-1102-1387', 'http://dx.doi.org/10.1007/s11235-018-0481-x', 'https://tartarus.org/martin/', 'http://dx.doi.org/10.1007/s12652-018-1126-3', 'http://dx.doi.org/10.1007/s00521-018-3442-0', 'https://orcid.org/0000-0002-0832-0362', 'B.Sc', '10.1016/j.cie.2018.11.007', '10.1007/s00366-018-00696-8', 'http://dx.doi.org/10.1007/s00366-018-00696-8', '10.1007/s12652-018-1126-3', 'T.Fj'], 'arxiv': ['1408.5882', '1508.04025', '1607.00976', '1708.00524', '1801.01078', '1611.01603']}
# -------------------------------------------------------------
# meta:  {'CrossMarkDomains[2]': 'sciencedirect.com', 'CreationDate': "D:20160831165843+05'30'", 'CrossmarkMajorVersionDate': '2010-04-23', 'Subject': 'Digital Communications and Networks, 2 + (2016) 108-121. doi:10.1016/j.dcan.2016.06.002', 'Author': 'S.K. Bharti', 'Creator': 'Elsevier', 'Keywords': 'Big data; Flume; Hadoop; Hive; MapReduce; Sarcasm; Sentiment; Tweets', 'ElsevierWebPDFSpecifications': '6.5', 'CrossmarkDomainExclusive': 'true', 'robots': 'noindex', 'ModDate': "D:20160831165843+05'30'", 'doi': '10.1016/j.dcan.2016.06.002', 'CrossMarkDomains[1]': 'elsevier.com', 'Title': 'Sarcastic sentiment detection in tweets streamed in real time_ a big data approach', 'dc': {'format': 'application/pdf', 'identifier': 'doi:10.1016/j.dcan.2016.06.002', 'title': {'x-default': 'Sarcastic sentiment detection in tweets streamed in real time_ a big data approach'}, 'creator': ['S.K. Bharti', 'B. Vachha', 'R.K. Pradhan', 'K.S. Babu', 'S.K. Jena'], 'subject': ['Big data', 'Flume', 'Hadoop', 'Hive', 'MapReduce', 'Sarcasm', 'Sentiment', 'Tweets'], 'publisher': ['Elsevier'], 'description': {'x-default': 'Digital Communications and Networks, 2 + (2016) 108-121. doi:10.1016/j.dcan.2016.06.002'}}, 'http://prismstandard.org/namespaces/basic/3.0/': {'aggregationType': 'journal', 'publicationName': 'Digital Communications and Networks', 'copyright': '© 2016 Chongqing University of Posts and Telecommunications. Production and Hosting by Elsevier B.V.', 'issn': '2352-8648', 'volume': '2', 'number': '3', 'coverDate': '2016-08-01', 'pageRange': '108-121', 'startingPage': '108', 'endingPage': '121', 'doi': '10.1016/j.dcan.2016.06.002', 'url': 'http://dx.doi.org/10.1016/j.dcan.2016.06.002'}, 'crossmark': {'MajorVersionDate': '2010-04-23', 'CrossmarkDomainExclusive': 'true', 'DOI': '10.1016/j.dcan.2016.06.002', 'CrossMarkDomains': ['elsevier.com', 'sciencedirect.com']}, 'pdfx': {'f': '5b07d5aa-d850-4c6b-a480-c7a5e0f3e64b:1553721348          ', 'doi': '10.1016/j.dcan.2016.06.002', 'CrossmarkMajorVersionDate': '2010-04-23', 'CrossmarkDomainExclusive': 'true', 'robots': 'noindex', 'CrossMarkDomains': ['elsevier.com', 'sciencedirect.com']}, 'http://www.niso.org/schemas/jav/1.0/': {'journal_article_version': 'VoR'}, 'xap': {'CreatorTool': 'Elsevier', 'ModifyDate': '2016-08-31T16:58:43+05:30', 'CreateDate': '2016-08-31T16:58:43+05:30', 'MetadataDate': '2016-08-31T16:58:43+05:30'}, 'rights': {'Marked': 'True'}, 'pdf': {'Keywords': 'Big data; Flume; Hadoop; Hive; MapReduce; Sarcasm; Sentiment; Tweets'}, 'xapmm': {'DocumentID': 'uuid:5d73da6e-13f5-42c5-b9ea-c231d0577f65', 'InstanceID': 'uuid:aee19b28-8e6c-4d13-a1fd-88cbbe3b887c'}, 'http://www.niso.org/schemas/ali/1.0/': {'license_ref': ['\n                  ']}, 'Pages': 14}
# references:  {'url': ['http://dx.doi.org/10.1016/j.dcan.2016.06.002', 'mailto:ksathyababu@nitrkl.ac.in', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref22', 'www.sciencedirect.com/science/journal/23528648', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref41', 'http://crossmark.crossref.org/dialog/?doi=10.1016/j.dcan.2016.06.002&domain=pdf', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref15', 'http://hadoop.apache.org/〉', 'http://apiwiki.twitter.com/Streaming-', 'http://hadoop.apache.org/', 'http://www.blog', 'mailto:skjena@nitrkl.ac.in', 'http://www.apiwiki.twitter.com/', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref8', 'http://www', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref43', 'www.elsevier.com/locate/dcan', 'http://www.smartinsights.com/social-media-marketing/social-media-strategy/new-global-social-media-research/', 'http://creativecommons.org/licenses/by-nc-nd/4.0/', 'http://blog〉', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref2', 'mailto:bakhtyarvachha@gmail.com', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref47', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref28', 'http://ﬂume.apache.org/〉', 'http://www.flume.apache.org/', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref17', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref32', 'ac.in', 'smartinsights.com/social-media-marketing/social-media-strategy/new-glo', 'http://apiwiki.twitter.com/〉', 'mailto:ramkrushna768@gmail.com', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref4', 'http://www.apiwiki.twitter.com/Streaming-API-Documentation/', 'mailto:sbharti1984@gmail.com', 'http://refhub.elsevier.com/S2352-8648(16)30027-X/sbref9'], 'arxiv': ['1403.7400']}
# -------------------------------------------------------------
# meta:  {'CreationDate': "D:20160725121310-04'00'", 'Creator': 'TeX', 'ModDate': "D:20160927071741-04'00'", 'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1', 'Producer': 'pdfTeX-1.40.16', 'Trapped': 'False', 'xap': {'CreateDate': '2016-07-25T12:13:10-04:00', 'CreatorTool': 'TeX', 'ModifyDate': '2016-09-27T07:17:41-04:00', 'MetadataDate': '2016-09-27T07:17:41-04:00'}, 'pdfx': {'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015) kpathsea version 6.2.1'}, 'pdf': {'Producer': 'pdfTeX-1.40.16', 'Trapped': 'False'}, 'dc': {'format': 'application/pdf'}, 'xapmm': {'DocumentID': 'uuid:a2113d9f-8656-4757-b6f3-70a1c7b30167', 'InstanceID': 'uuid:930cfa39-181c-4104-9144-a83d94be151c'}, 'Pages': 10}
# references:  {'url': ['textblob.readthedocs.org/en/dev/', 'scikit-learn.org/', 'twimg.com', 'unito.it', 'www.nltk.org/', 't.co', 'www.merriam-webster.com/dictionary/sarcasm', '1408.5093', 'catalog.ldc.upenn.edu/LDC2006T13', 'inc.com', 'http://dx.doi.org/10.1145/2964284.2964321']}
# -------------------------------------------------------------
# meta:  {'ModDate': "D:20170716081506+04'30'", 'CreationDate': "D:20170716081506+04'30'", 'Title': 'Figurative messages and affect in Twitter: Differences between #irony, #sarcasm and #not', 'Creator': 'Daneshyari.com', 'Producer': 'Daneshyari.com', 'Pages': 3}
# references:  {'url': ['http://dx.doi.org/10.1016/j.knosys.2016.05.035', 'www.elsevier.com/locate/knosys', 'http://www.ScienceDirect.com', 'http://daneshyari.com/article/571794', 'http://crossmark.crossref.org/dialog/?doi=10.1016/j.knosys.2016.05.035&domain=pdf', 'mailto:sulis@di.unito.it', 'unito.it', 'http://www.elsevier.com/locate/knosys']}
# -------------------------------------------------------------
# meta:  {'IEEE Issue ID': '7959951', 'Creator': 'LaTeX + confproc v0.7', 'Producer': 'Acrobat Distiller 8.1.0 (Windows); modified using iText® 7.1.1 ©2000-2018 iText Group NV (AGPL-version)', 'IEEE Article ID': '7959995', 'Title': 'Impact analysis of emotion in figurative language', 'IEEE Publication ID': '7951674', 'Meeting Ending Date': '26 May 2017', 'Meeting Starting Date': '24 May 2017', 'Subject': '2017 IEEE/ACIS 16th International Conference on Computer and Information Science (ICIS);2017; ; ;10.1109/ICIS.2017.7959995', 'ModDate': "D:20181211040356-05'00'", 'CreationDate': "D:20170620202735+05'30'", 'dc': {'format': 'application/pdf', 'publisher': ['IEEE'], 'description': '2017 IEEE/ACIS 16th International Conference on Computer and Information Science (ICIS);2017; ; ;10.1109/ICIS.2017.7959995', 'subject': ['Figurative Language', 'Humor', 'Irony', 'Sarcasm', 'Satire', 'Emotion Detection', 'Class-imbalanced problem'], 'title': 'Impact analysis of emotion in figurative language', 'creator': ['Pyae Phyo Thu', 'Nwe New']}, 'http://prismstandard.org/namespaces/basic/3.0/': {'publicationName': '2017 IEEE/ACIS 16th International Conference on Computer and Information Science (ICIS)', 'startingPage': '209', 'coverDisplayDate': '  May 2017', 'doi': '10.1109/ICIS.2017.7959995', 'endingPage': '214'}, 'Pages': 6}
# references:  {'url': ['http://www.tweepy.org', '10.3758/s13428-016-0743-z']}
# -------------------------------------------------------------

# %%
#!/usr/bin/env python
paperdirectory = "/Users/fernandodurier/Desktop/sarcasm-paper-review"
import os
import tika
from tika import parser
set_of_refs_tika = []
for root, dirs, files in os.walk(paperdirectory, topdown=False):
    for name in files:
        if ".pdf" in name:
            pdfpath = os.path.join(root, name)
            parsed = parser.from_file(pdfpath)
            pdfmeta = parsed['metadata']
            set_of_refs_tika.append(pdfmeta)

# %%
print('-------------------------------------------------------------')
for ref in set_of_refs_tika:
    print("keys:", ref.keys())
    
#     if 'Keywords' in ref.keys():
#         print('keywords: ', ref['Keywords'])
        
#     elif 'meta:keyword' in ref.keys():
#         print('keywords: ', ref['meta:keyword'])
        
#     elif 'dc:subject' in ref.keys():
#         print('keywords: ', ref['dc:subject']) 
    
    print('-------------------------------------------------------------')
# Out:
# -------------------------------------------------------------
# -------------------------------------------------------------
# keywords:  Fine-Grained Opinion Mining; Ideology Detection; Sarcasm Detection
# -------------------------------------------------------------
# keywords:
# -------------------------------------------------------------
# keywords:
# -------------------------------------------------------------
# -------------------------------------------------------------
# keywords:
# -------------------------------------------------------------
# -------------------------------------------------------------
# -------------------------------------------------------------
# keywords:  Irony detection; Text mining; Twitter; Politics
# -------------------------------------------------------------
# -------------------------------------------------------------
# -------------------------------------------------------------
# keywords:
# -------------------------------------------------------------
# -------------------------------------------------------------
# keywords:  Big data; Flume; Hadoop; Hive; MapReduce; Sarcasm; Sentiment; Tweets
# -------------------------------------------------------------
# -------------------------------------------------------------
# -------------------------------------------------------------
# -------------------------------------------------------------

# %%
data = []
for root, dirs, files in os.walk(paperdirectory, topdown=False):
    for name in files:
        if "-deep.json" in name:
            with open(paperdirectory+"/"+name) as f:
                d = json.load(f)
                data.append(d)

# %%
print('------------------------------------------------------------')
for d in data:
    print("authors: ", d['clean-authors'])
    print("title: ", d['title'])
    print("pub_date: ", d['pub_date'])
    print("keywords: ", d['keywords'])
    print('------------------------------------------------------------')
# Out:
# ------------------------------------------------------------
# authors:  ['Martin Flintham', 'Christian Karner', 'Khaled Bachour', 'Helen Creswick', 'Neha Gupta', 'Stuart Moran']
# title:  Falling for Fake News: Investigating the Consumption of News via Social Media
# pub_date:  {'year': '2018'}
# keywords:  None
# ------------------------------------------------------------
# authors:  [{'@contrib-type': 'author', 'email': 'e.kapogianni@kent.ac.uk', 'string-name': 'Eleni Kapogianni', 'xref': {'#text': '0', '@ref-type': 'aff', '@rid': 'aff0'}}]
# title:  The ironic operation: Revisiting the components of ironic meaning
# pub_date:  {'year': '2015'}
# keywords:  ['Irony', 'Ironic operation', 'Ironic vehicle', '(Direct) ironic output']
# ------------------------------------------------------------
# authors:  ['Kai Shuy', 'Amy Slivaz', 'Suhang Wangy', 'Jiliang Tang \\', 'Huan Liuy']
# title:  Fake News Detection on Social Media: A Data Mining Perspective
# pub_date:  None
# keywords:  None
# ------------------------------------------------------------
# authors:  ['Dubai', 'United Arab Emirates', 'c a Jihen Karoui', 'Farah BSanoa', 'rla MZit', 'Ve´ronique Moriceau']
# title:  SOUKHRIA: Towards an Irony Detection System for Arabic in 2017, Dubai, United Arab Emirates Social Media SOUKHRIA: Towards an Irony Detection System for Arabic in
# pub_date:  {'year': '2017'}
# keywords:  ['Arabic tweets', 'opinion analysis', 'irony detection', 'supervised learning']
# ------------------------------------------------------------
# authors:  ['Manjusha P D', 'M. Tech Student', 'QL manjushapda@gmail.com']
# title:  Convolutional Neural Network based Simile Classification System
# pub_date:  {'year': '2018'}
# keywords:  None
# ------------------------------------------------------------
# authors:  ['H M Keerthi Kumar', 'B S Harish', 'H M Keerthi Kumar', 'B S Harish']
# title:  Sarcasm classification: A novel approach by using Content Based Sarcasm classification: A novel approach by using Content Based Sarcasm classification: A novel approach by using Content Based Feature Selection Method Feature Selection Method Feature Selection Method
# pub_date:  {'year': '2018'}
# keywords:  ['Sarcasm', 'Classification', 'Feature Selection', 'k-means clustering']
# ------------------------------------------------------------
# authors:  ['LE HOANG SON', 'AKSHI KUMAR', 'SAURABH RAJ SANGWAN', 'ANSHIKA ARORA', 'ANAND NAYYAR', 'MOHAMED ABDEL-BASSET']
# title:  Sarcasm Detection Using Soft Attention-Based Bidirectional Long Short-Term Memory Model With Convolution Network
# pub_date:  {'year': '2019'}
# keywords:  ['Sarcasm', 'deep learning', 'attention', 'social data']
# ------------------------------------------------------------
# authors:  ['Rossano Schifanella', 'Paloma de Juan', 'Liangliang Cao', 'Joel Tetreault', 'Sarcasm; Social Media; Multimodal; Deep Learning; NLP']
# title:  Detecting Sarcasm in Multimodal Social Platforms
# pub_date:  None
# keywords:  None
# ------------------------------------------------------------
# authors:  [{'@contrib-type': 'author', 'email': 'nwenwemdy08@gmail.com', 'string-name': 'Nwe Nwe', 'xref': {'#text': '0', '@ref-type': 'aff', '@rid': 'aff0'}}]
# title:  None
# pub_date:  {'year': '2017'}
# keywords:  None
# ------------------------------------------------------------
# authors:  ['S.K. Bharti n', 'B. Vachha', 'R.K. Pradhan', 'K.S. Babu', 'S.K. Jena']
# title:  Sarcastic sentiment detection in tweets streamed in real time: a big data approach
# pub_date:  {'year': '2016'}
# keywords:  ['Big data', 'Flume', 'Hadoop', 'Hive', 'MapReduce', 'Sarcasm', 'Sentiment', 'Tweets']
# ------------------------------------------------------------
# authors:  [None]
# title:  Fake News or Truth? Using Satirical Cues to Detect Potentially Misleading News.
# pub_date:  {'year': '2016'}
# keywords:  None
# ------------------------------------------------------------
# authors:  ['Giuseppe Castellucci', 'Danilo Croce', 'Roberto Basili']
# title:  Context-aware Convolutional Neural Networks for Twitter Sentiment Analysis in Italian
# pub_date:  None
# keywords:  None
# ------------------------------------------------------------
# authors:  ['Fan Yang and Arjun Mukherjee', 'Eduard Gragut']
# title:  Satirical News Detection and Analysis using Attention Mechanism and Linguistic Features
# pub_date:  None
# keywords:  None
# ------------------------------------------------------------
# authors:  [{'@contrib-type': 'author', 'email': 's.kannangara@unsw.edu.au', 'string-name': 'Sandeepa Kannangara', 'xref': {'#text': '0', '@ref-type': 'aff', '@rid': 'aff0'}}]
# title:  Mining Twiter for Fine-Grained Political Opinion Polarity Classification, Ideology Detection and Sarcasm Detection
# pub_date:  {'year': '2018'}
# keywords:  None
# ------------------------------------------------------------
# authors:  ['Basilis Charalampakis', 'Dimitris Spathis n', 'Elias Kouslis', 'Katia Kermanidis']
# title:  A comparison between semi-supervised and supervised text mining techniques on detecting irony in greek political tweets
# pub_date:  {'year': '2016'}
# keywords:  ['Irony detection', 'Text mining', 'Twitter', 'Politics']
# ------------------------------------------------------------
# authors:  ['Rafael A. Monteiro', 'Roney L. S. Santos', 'Thiago A. S. Pardo', 'Tiago A. de Almeida', 'Evandro E. S. Ruiz', 'Oto A. Vale']
# title:  Contributions to the Study of Fake News in Portuguese: New Corpus and Automatic Detection Results
# pub_date:  None
# keywords:  ['Fake news', 'Reference corpus', 'Linguistic features', 'Machine learning']
# ------------------------------------------------------------
